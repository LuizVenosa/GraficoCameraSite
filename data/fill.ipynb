# %%
import pandas as pd

data = pd.read_csv('legislaturas.csv', sep=';')

# %%
partidos = pd.read_csv('partidos.csv')

# %%
data
# Out:
#     idLegislatura                                                uri  \
# 0              57  https://dadosabertos.camara.leg.br/api/v2/legi...
# 1              56  https://dadosabertos.camara.leg.br/api/v2/legi...
# 2              55  https://dadosabertos.camara.leg.br/api/v2/legi...
# 3              54  https://dadosabertos.camara.leg.br/api/v2/legi...
# 4              53  https://dadosabertos.camara.leg.br/api/v2/legi...
# 5              52  https://dadosabertos.camara.leg.br/api/v2/legi...
# 6              51  https://dadosabertos.camara.leg.br/api/v2/legi...
# 7              50  https://dadosabertos.camara.leg.br/api/v2/legi...
# 8              49  https://dadosabertos.camara.leg.br/api/v2/legi...
# 9              48  https://dadosabertos.camara.leg.br/api/v2/legi...
# 10             47  https://dadosabertos.camara.leg.br/api/v2/legi...
# 11             46  https://dadosabertos.camara.leg.br/api/v2/legi...
# 12             45  https://dadosabertos.camara.leg.br/api/v2/legi...
# ...

# %%
leg57 = data.loc[data['idLegislaturaFinal'] == 57]

# %%
leg57 = leg57[['Nome', 'UF']]
